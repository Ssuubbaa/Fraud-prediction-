# %%
# Import libraries and load data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Fraud.csv')

# %%
# Data exploration
print(df.shape) # number of rows and columns
# Out:
# (5233719, 11)

# %% [markdown]
# Unable to get complete rows..it taking time to upload the files

# %% [markdown]
# # Unable to get complete rows..it taking time to upload the files

# %%
df.head() # first few rows of data
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0      0.0             0.0
# 1  M2044282225             0.0             0.0      0.0             0.0
# 2   C553264065             0.0             0.0      1.0             0.0
# 3    C38997010         21182.0             0.0      1.0             0.0
# 4  M1230701703             0.0             0.0      0.0             0.0

# %%
# Check for missing values
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    1
# isFraud           1
# isFlaggedFraud    1
# dtype: int64

# %%
# Check the data types of the columns
print("Data types:", df.dtypes)
# Out:
# Data types: step                int64
# type               object
# amount            float64
# nameOrig           object
# oldbalanceOrg     float64
# newbalanceOrig    float64
# nameDest           object
# oldbalanceDest    float64
# newbalanceDest    float64
# isFraud           float64
# isFlaggedFraud    float64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
df.describe()
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  5.233718e+06  5.233718e+06   5.233718e+06    5.233718e+06
# mean   1.989668e+02  1.812113e+05   8.421240e+05    8.639271e+05
# std    1.072040e+02  6.363482e+05   2.921326e+06    2.958091e+06
# min    1.000000e+00  0.000000e+00   0.000000e+00    0.000000e+00
# 25%    1.360000e+02  1.323565e+04   0.000000e+00    0.000000e+00
# 50%    2.080000e+02  7.515306e+04   1.397700e+04    0.000000e+00
# 75%    2.850000e+02  2.091914e+05   1.075290e+05    1.452262e+05
# max    3.710000e+02  9.244552e+07   4.381886e+07    4.368662e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    5.233718e+06    5.233718e+06  5.233718e+06    5.233718e+06
# mean     1.074929e+06    1.204666e+06  7.908336e-04    5.732063e-07
# std      3.200062e+06    3.531848e+06  2.811064e-02    7.571037e-04
# min      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# ...

# %%
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()
# Out:
# <ipython-input-11-787941b06462>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='coolwarm')

# %%
from sklearn.model_selection import train_test_split
x=dataset[['oldbalanceOrg','newbalanceOrig']].values
y=dataset['isFraud'].values
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state =0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-abc4f23de0c2> in <cell line: 2>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x=dataset[['oldbalanceOrg','newbalanceOrig']].values
#       3 y=dataset['isFraud'].values
#       4 X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state =0)
#
# NameError: name 'dataset' is not defined
